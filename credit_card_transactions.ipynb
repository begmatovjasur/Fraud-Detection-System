# %%
import pandas as pd
import psycopg2

# %%
connection = psycopg2.connect(
        dbname = 'demo',
        user = 'postgres',
        password = '19781981'
        
)
sql_kod = """ 
SELECT * FROM credit_card_transactions;
"""
df = pd.read_sql(sql_kod, connection)
df.head()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11604\679435392.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql_kod, connection)
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          v8        v9  ...       v21       v22       v23       v24       v25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    284807 non-null  float64
#  1   v1      284807 non-null  float64
#  2   v2      284807 non-null  float64
#  3   v3      284807 non-null  float64
#  4   v4      284807 non-null  float64
#  5   v5      284807 non-null  float64
#  6   v6      284807 non-null  float64
#  7   v7      284807 non-null  float64
#  8   v8      284807 non-null  float64
#  9   v9      284807 non-null  float64
#  10  v10     284807 non-null  float64
#  11  v11     284807 non-null  float64
#  12  v12     284807 non-null  float64
#  13  v13     284807 non-null  float64
#  14  v14     284807 non-null  float64
#  15  v15     284807 non-null  float64
#  16  v16     284807 non-null  float64
#  17  v17     284807 non-null  float64
#  18  v18     284807 non-null  float64
#  19  v19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# time      0
# v1        0
# v2        0
# v3        0
# v4        0
# v5        0
# v6        0
# v7        0
# v8        0
# v9        0
# v10       0
# v11       0
# v12       0
# v13       0
# v14       0
# v15       0
# v16       0
# v17       0
# v18       0
# v19       0
# v20       0
# v21       0
# v22       0
# v23       0
# v24       0
# v25       0
# v26       0
# v27       0
# v28       0
# amount    0
# class     0
# dtype: int64

# %%
df[df['class'] == 1]['amount'].mean()
# Out:
# np.float64(122.21132113821139)

# %%
df[df['class'] == 1]['amount'].max()
# Out:
# 2125.87

# %%
df[df['class'] == 0]['amount'].mean()
# Out:
# np.float64(88.29102242231328)

# %%
df[df['class'] == 0]['amount'].max()
# Out:
# 25691.16

# %%
df['time_in_hours'] = df['time']/3600

# %%
df.head()
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          v8        v9  ...       v22       v23       v24       v25       v26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, axes = plt.subplots(1,2, figsize = (16,6))

sns.histplot(df[df['class'] == 1]['time_in_hours'], bins = 48, color='red', ax = axes[0])
axes[0].set_title('Firibgarlik tranzaksiyalari')
axes[0].set_xlabel('Vaqt')
axes[0].set_ylabel('Tranzaksiyalar soni')

sns.histplot(df[df['class'] == 0]['time_in_hours'], bins = 48, color = 'blue', ax = axes[1])
axes[1].set_title('Toza tranzaksiyalar')
axes[1].set_xlabel('Vaqt')
axes[1].set_ylabel('Tranzaksiyalar soni')

plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay 
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
X = df.drop(columns=(['time_in_hours','class']))
y = df['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
model = LogisticRegression(class_weight='balanced')
model.fit(X_train,y_train)
# Out:
# c:\Users\Asus\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced')

# %%
prediction = model.predict(X_test)
acc = accuracy_score(prediction,y_test)
print(f"Accuracy {acc}")
# Out:
# Accuracy 0.9620916868555646

# %%
ConfusionMatrixDisplay.from_estimator(model,X_test,y_test, cmap='Blues')
plt.show()

# %%
model_rf = RandomForestClassifier(n_estimators=100, class_weight='balanced')
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
prediction_rf = model_rf.predict(X_test)
acc_rf = accuracy_score(prediction_rf,y_test)
print(f"Accuracy: {acc_rf}")
# Out:
# Accuracy: 0.9995318516437859

# %%
ConfusionMatrixDisplay.from_estimator(model_rf,X_test,y_test, cmap='Blues')
plt.show()

# %%
y_prob = model_rf.predict_proba(X_test)[:,1]
threshold = 0.3
y_hat = (y_prob > threshold).astype(int)
ConfusionMatrixDisplay.from_predictions(y_hat,y_test, cmap='Blues')
plt.show()

# %%
# !pip install SHAP
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [SHAP]
#    -------------------- ------------------- 1/2 [SHAP]
#    -------------------- ------------------- 1/2 [SHAP]
#    -------------------- ------------------- 1/2 [SHAP]
#    -------------------- ------------------- 1/2 [SHAP]
#    ---------------------------------------- 2/2 [SHAP]
#
# ...

# %% [markdown]
# ### SHAP Analysis
#
# Random Forest "Qora quti" (Black-box) model bo'lganligi sababli, uning qarorlarini biznes tili bilan tushuntirish uchun **SHAP (SHapley Additive exPlanations)** kutubxonasidan foydalandik. Yuqoridagi Summary Plot modelimizning arxitekturasini to'liq ochib beradi.
#
# **Asosiy xulosalar:**
# 1. **Eng muhim omillar:** `V12`, `V14`, `V4` va `V11` ustunlari firibgarlikni aniqlashda eng katta vaznga ega. Model tranzaksiyani bloklashdan oldin birinchi navbatda shu ko'rsatkichlarni tekshiradi.
# 2. **Teskari korrelyatsiya (V12 va V14):** Grafikdan ko'rinib turibdiki, ushbu o'zgaruvchilarning qiymati keskin pasayishi (ko'k nuqtalar) tranzaksiyaning firibgarlik ehtimolini (SHAP value > 0) yuqori darajada oshiradi.
# 3. **To'g'ri korrelyatsiya (V4 va V11):** Aksincha, bu ko'rsatkichlarning oshib ketishi (qizil nuqtalar) modelga shubhali faollik haqida kuchli signal yuboradi.
#
# Bu tahlil bank xavfsizlik bo'limiga nafaqat firibgarlarni ushlashda, balki ularning qanday mantiq asosida harakat qilayotganini tushunishda yordam beradi.

# %%
import shap

# %%
explainer = shap.TreeExplainer(model_rf)
X_test_sample = X_test.sample(n=200, random_state=42)

# %%
shap_values = explainer.shap_values(X_test_sample)

# %%
shap.summary_plot(shap_values[:, :, 1], X_test_sample)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report

# %%
weight = y_train.value_counts()[0] / y_train.value_counts()[1]
model_xgb = XGBClassifier(
    n_estimators=100, 
    scale_pos_weight=weight, 
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss'
)
model_xgb.fit(X_train, y_train)
# Out:
# c:\Users\Asus\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:22:06] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
y_pred_xgb = model_xgb.predict(X_test)
acc_xg = accuracy_score(y_pred_xgb,y_test)
print(f"Accuracy: {acc_xg}")
# Out:
# Accuracy: 0.9996137776061234

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_xgb, cmap='Blues')
plt.title("XGBoost Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85300
#            1       0.93      0.83      0.88       143
#
#     accuracy                           1.00     85443
#    macro avg       0.96      0.92      0.94     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
import joblib

joblib.dump(model_xgb, 'xgboost_fraud_model.pkl')
# Out:
# ['xgboost_fraud_model.pkl']
